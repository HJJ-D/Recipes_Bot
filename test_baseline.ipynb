# %%
import os, re, json
from typing import List, Dict, Any, Tuple
import chromadb
from chromadb.utils import embedding_functions
import google.generativeai as genai
from difflib import SequenceMatcher
import pandas as pd
from tqdm import tqdm
import re
import ast

# ==========================================================
DB_PATH = "vector_new_db/recipes"   # your ChromaDB path
MODEL_NAME = "gemini-2.0-flash-lite"
GENAI_API_KEY = os.getenv('GENAI_API_KEY') 

TOP_K_DEFAULT = 3
OUTPUT_DIR = "/content/evaluation_results"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ==========================================================
chroma_client = chromadb.PersistentClient(path=DB_PATH)
embedder = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="BAAI/bge-m3"
)
collection = chroma_client.get_collection("recipes")

# ==========================================================
genai.configure(api_key=GENAI_API_KEY)
model = genai.GenerativeModel(MODEL_NAME)

# ==========================================================
TOKEN_CLEAN_RE = re.compile(r"[^a-zA-Z0-9\s\-]")
STOP_TOKENS = {"fresh","dried","chopped","sliced","minced","ground","crushed",
    "thinly","thick","thickly","small","medium","large","whole","skinless",
    "boneless","lean","extra","optional","to","taste","of","and","or"}

CANONICAL_MAP = {
    "chicken thigh":"chicken","chicken thighs":"chicken","chicken breast":"chicken",
    "beef rib":"beef ribs","beef ribs":"beef ribs","pork belly":"pork belly",
    "pork ribs":"pork ribs","pork":"pork",
    "tofu":"tofu","tofu skin":"yuba","bean curd skin":"yuba","yuba":"yuba",
    "garlic":"garlic","ginger":"ginger","chili oil":"chili oil",
    "soy sauce":"soy sauce","doubanjiang":"doubanjiang"
}
CONFLICTS = {("tofu","yuba"),("yuba","tofu")}

def _normalize(s:str)->str:
    s = s.lower().strip()
    s = TOKEN_CLEAN_RE.sub(" ", s)
    return re.sub(r"\s+"," ",s).strip()

def _canonicalize(s:str)->str:
    s_norm=_normalize(s)
    for k in sorted(CANONICAL_MAP,key=len,reverse=True):
        if re.search(rf"(?<![a-z0-9]){re.escape(k)}(?![a-z0-9])",s_norm):
            return CANONICAL_MAP[k]
    return s_norm

def _is_conflict(a,b): return (a,b) in CONFLICTS
def _similar(a,b): return SequenceMatcher(None,a,b).ratio()

def match_ing(a,b,th=0.88):
    a,b=_canonicalize(a),_canonicalize(b)
    if _is_conflict(a,b): return False
    if a==b: return True
    if re.search(rf"(?<![a-z0-9]){re.escape(a)}(?![a-z0-9])",b) or re.search(rf"(?<![a-z0-9]){re.escape(b)}(?![a-z0-9])",a):
        return True
    return _similar(a,b)>=th

# ==========================================================
class RecipeModelEvaluator:
    def __init__(self,collection,embedder,model,top_k:int=3):
        self.collection=collection
        self.embedder=embedder
        self.model=model
        self.top_k=top_k

    def _retrieve_recipes(self,query:str)->List[Dict[str,Any]]:
        emb=self.embedder([query])[0]
        res=self.collection.query(query_embeddings=[emb],n_results=self.top_k)
        docs=res.get("documents",[[]])[0]
        metas=res.get("metadatas",[[]])[0]
        out=[]
        for i in range(min(len(docs),self.top_k)):
            m=metas[i]
            out.append({
                "name":m.get("Recipes_name",""),
                "flavor":m.get("Flavor",""),
                "difficulty":m.get("Difficulty",""),
                "time":m.get("Estimated Cooking Time",""),
                "doc":docs[i]
            })
        return out

    def _build_prompt(self,query:str,cands:List[Dict[str,Any]])->str:
        blocks=[]
        for i,c in enumerate(cands,1):
            blocks.append(f"[Candidate {i}]\nName:{c['name']}\nFlavor:{c['flavor']}\nContent:\n{c['doc']}")
        schema={
            "recipe_name":"string",
            "chosen_from":"string",
            "ingredients":["string","..."],
            "steps":["string","..."],
        }
        return f"""
User request:
{query}

Output exactly ONE JSON object following this schema:
{json.dumps(schema,indent=2)}
"""

    def generate_recipe(self,prompt:str)->str:
        cands=self._retrieve_recipes(prompt)
        print(f"📦 Retrieved {len(cands)} candidates from Chroma")
        llm_prompt=self._build_prompt(prompt,cands)
        try:
            resp=self.model.generate_content(llm_prompt)
            return resp.text
        except Exception as e:
            return json.dumps({"recipe_name":"ERROR","chosen_from":"ERROR","ingredients":[],"steps":[],"reasoning":str(e)})

    def parse_json(self,text:str)->Dict[str,Any]:
        try: return json.loads(text)
        except: pass
        m=re.search(r"(\{.*\})",text,flags=re.DOTALL)
        if m:
            try: return json.loads(m.group(1))
            except: pass
        return {"recipe_name":"NO_MATCH","chosen_from":"NO_MATCH","ingredients":[],"steps":[],"reasoning":""}

    def calc_recall(self,user_ings:List[str],gen_ings:List[str])->Dict[str,Any]:
        u=[_normalize(x) for x in user_ings]
        g=[_normalize(x) for x in gen_ings]
        match=[]
        mg=set()
        for ui in u:
            for j,gi in enumerate(g):
                if j in mg: continue
                if match_ing(ui,gi):
                    match.append((ui,gi)); mg.add(j); break
        r=len(match)/len(u) if u else 0
        p=len(match)/len(g) if g else 0
        f=2*r*p/(r+p) if (r+p)>0 else 0
        return {"matched":len(match),"recall":r,"precision":p,"f1":f,"pairs":match}

# ==========================================================
model_eval = RecipeModelEvaluator(collection,embedder,model)


# ===== basic setting =====
df = pd.read_csv("recipes_prompt_label.csv")
df = df.iloc[0:600] # test on first 600 samples
BATCH_SIZE = 50
OUTPUT_DIR = "outputs/baseline"
os.makedirs(OUTPUT_DIR, exist_ok=True)

all_results = []  # store all metrics here

for i in tqdm(range(0, len(df), BATCH_SIZE), desc="Evaluating recipes"):
    batch = df.iloc[i:i + BATCH_SIZE]
    docs = batch["prompt"].tolist()
    ids = batch["ingredients/label"].tolist()

    for j, (prompt, gold_ings_raw) in enumerate(zip(docs, ids)):
        print("\n" + "=" * 80)
        print(f"🧩 Sample {i + j + 1}/{len(df)}")

        print("\n🔍 Prompt:", prompt)
        print("🎯 Ground Truth (raw):", gold_ings_raw)

        if isinstance(gold_ings_raw, str):
            try:
                gold_ings = ast.literal_eval(gold_ings_raw)
                if not isinstance(gold_ings, list):
                    gold_ings = [gold_ings]
            except Exception:
                gold_ings = [x.strip() for x in gold_ings_raw.split(",") if x.strip()]
        else:
            gold_ings = list(gold_ings_raw) if not isinstance(gold_ings_raw, list) else gold_ings_raw

        print("✅ Parsed Ground Truth (list):", gold_ings)

        raw_out = model_eval.generate_recipe(prompt)
        print("\n💬 Gemini Raw Output:\n", raw_out[:800])

        parsed = model_eval.parse_json(raw_out)
        gen_ings = parsed.get("ingredients", [])
        print("\n🥬 Extracted Ingredients:", gen_ings)

        metrics = model_eval.calc_recall(gold_ings, gen_ings)
        print("\n📊 Metrics:\n", json.dumps(metrics, indent=2, ensure_ascii=False))

        metrics_row = {"id": i + j + 1, "prompt": prompt}
        metrics_row.update(metrics)
        metrics_row["raw_output"] = raw_out
        all_results.append(metrics_row)

results_df = pd.DataFrame(all_results)
results_path = os.path.join(OUTPUT_DIR, "metrics_results.csv")
results_df.to_csv(results_path, index=False, encoding="utf-8-sig")

print(f"\n✅ 所有指标已保存到: {results_path}")
# Out:
# Evaluating recipes:   0%|          | 0/12 [00:00<?, ?it/s]
# ================================================================================
# 🧩 Sample 1/600
#
# 🔍 Prompt: I have pork belly, garlic, and chili oil. I want to make something spicy and Sichuan-style.
# 🎯 Ground Truth (raw): pork belly, garlic, chili oil
# ✅ Parsed Ground Truth (list): ['pork belly', 'garlic', 'chili oil']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Sichuan Pork Belly with Garlic and Chili Oil",
#   "chosen_from": "User Request and Common Sichuan Recipes",
#   "ingredients": [
#     "500g pork belly, cut into 1-inch cubes",
#     "2 tablespoons chili oil, plus extra for serving",
#     "4 cloves garlic, minced",
#     "1 tablespoon light soy sauce",
#     "1 tablespoon dark soy sauce",
#     "1 tablespoon Shaoxing wine (or dry sherry)",
#     "1 teaspoon Sichuan peppercorns, toasted and ground",
#     "1/2 teaspoon sugar",
#     "1/4 cup water or chicken broth",
#     "2 scallions, thinly sliced (for garnish)",
#     "Cooked rice, for serving"
#   ],
#   "steps": [
#     "In a pot, blanch the pork belly in boiling water for 5 minutes. Drain and rinse under cold water. This helps remove impurities.",
#     "Heat 1 tablespoon of chili o
#
# 🥬 Extracted Ingredients: ['500g pork belly, cut into 1-inch cubes', '2 tablespoons chili oil, plus extra for serving', '4 cloves garlic, minced', '1 tablespoon light soy sauce', '1 tablespoon dark soy sauce', '1 tablespoon Shaoxing wine (or dry sherry)', '1 teaspoon Sichuan peppercorns, toasted and ground', '1/2 teaspoon sugar', '1/4 cup water or chicken broth', '2 scallions, thinly sliced (for garnish)', 'Cooked rice, for serving']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.2727272727272727,
#   "f1": 0.42857142857142855,
#   "pairs": [
#     [
#       "pork belly",
#       "500g pork belly cut into 1-inch cubes"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ],
#     [
#       "chili oil",
#       "2 tablespoons chili oil plus extra for serving"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 2/600
#
# 🔍 Prompt: I have chicken thighs, soy sauce, and ginger. I want a simple Chinese home-style dish.
# 🎯 Ground Truth (raw): chicken thighs, soy sauce, ginger
# ✅ Parsed Ground Truth (list): ['chicken thighs', 'soy sauce', 'ginger']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Soy Sauce Ginger Chicken Thighs",
#   "chosen_from": "Simple pantry ingredients",
#   "ingredients": [
#     "4-6 chicken thighs",
#     "1/4 cup soy sauce",
#     "1 tablespoon grated fresh ginger",
#     "1 tablespoon cooking oil (vegetable, canola, or peanut)",
#     "1/4 cup water",
#     "Optional: 1 scallion, thinly sliced (for garnish)"
#   ],
#   "steps": [
#     "Pat chicken thighs dry with paper towels.",
#     "In a bowl, combine soy sauce and grated ginger.",
#     "Marinate chicken thighs in soy sauce mixture for at least 15 minutes (or up to an hour) at room temperature, flipping occasionally.",
#     "Heat cooking oil in a skillet or wok over medium-high heat.",
#     "Add chicken thighs to the hot skillet, skin-side down. Sear for 4-5 minutes until the skin is golden brown.",
#
# 🥬 Extracted Ingredients: ['4-6 chicken thighs', '1/4 cup soy sauce', '1 tablespoon grated fresh ginger', '1 tablespoon cooking oil (vegetable, canola, or peanut)', '1/4 cup water', 'Optional: 1 scallion, thinly sliced (for garnish)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.5,
#   "f1": 0.6666666666666666,
#   "pairs": [
#     [
#       "chicken thighs",
#       "4-6 chicken thighs"
#     ],
#     [
#       "soy sauce",
#       "1 4 cup soy sauce"
#     ],
#     [
#       "ginger",
#       "1 tablespoon grated fresh ginger"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 3/600
#
# 🔍 Prompt: I have tofu, bok choy, and mushrooms. I want something light and vegetarian like a soup.
# 🎯 Ground Truth (raw): tofu, bok choy, mushrooms
# ✅ Parsed Ground Truth (list): ['tofu', 'bok choy', 'mushrooms']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Tofu, Bok Choy, and Mushroom Soup",
#   "chosen_from": "User's Ingredients",
#   "ingredients": [
#     "1 block firm tofu, pressed and cubed",
#     "1 bunch bok choy, chopped",
#     "8 oz mushrooms, sliced",
#     "4 cups vegetable broth",
#     "1 tbsp soy sauce",
#     "1 tsp sesame oil",
#     "1/2 tsp grated ginger",
#     "1 clove garlic, minced",
#     "Salt and pepper to taste",
#     "Green onions, sliced (for garnish - optional)"
#   ],
#   "steps": [
#     "In a pot, heat vegetable broth over medium heat.",
#     "Add mushrooms and ginger to the broth and cook for 5 minutes.",
#     "Add tofu, bok choy, garlic, soy sauce, and sesame oil to the pot.",
#     "Cook until the bok choy is tender-crisp, about 5-7 minutes.",
#     "Season with salt and pepper to taste.",
#     "Garnish wi
#
# 🥬 Extracted Ingredients: ['1 block firm tofu, pressed and cubed', '1 bunch bok choy, chopped', '8 oz mushrooms, sliced', '4 cups vegetable broth', '1 tbsp soy sauce', '1 tsp sesame oil', '1/2 tsp grated ginger', '1 clove garlic, minced', 'Salt and pepper to taste', 'Green onions, sliced (for garnish - optional)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3,
#   "f1": 0.4615384615384615,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm tofu pressed and cubed"
#     ],
#     [
#       "bok choy",
#       "1 bunch bok choy chopped"
#     ],
#     [
#       "mushrooms",
#       "8 oz mushrooms sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 4/600
#
# 🔍 Prompt: I have beef slices, bell peppers, and onions. I want to make a stir-fry that's slightly spicy.
# 🎯 Ground Truth (raw): beef slices, bell peppers, onions
# ✅ Parsed Ground Truth (list): ['beef slices', 'bell peppers', 'onions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Beef and Pepper Stir-Fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb beef slices (sirloin or flank steak, thinly sliced)",
#     "1 large bell pepper (any color), sliced",
#     "1 medium onion, sliced",
#     "2 cloves garlic, minced",
#     "1 inch ginger, grated",
#     "1-2 Thai chilies, finely chopped (adjust to your spice preference)",
#     "2 tablespoons soy sauce",
#     "1 tablespoon oyster sauce (optional)",
#     "1 tablespoon cornstarch",
#     "1 tablespoon vegetable oil",
#     "1 teaspoon sesame oil",
#     "Cooked rice, for serving"
#   ],
#   "steps": [
#     "In a small bowl, whisk together soy sauce, oyster sauce (if using), and cornstarch. Set aside.",
#     "Heat vegetable oil in a wok or large skillet over high heat until shimmering.",
#     "Ad
#
# 🥬 Extracted Ingredients: ['1 lb beef slices (sirloin or flank steak, thinly sliced)', '1 large bell pepper (any color), sliced', '1 medium onion, sliced', '2 cloves garlic, minced', '1 inch ginger, grated', '1-2 Thai chilies, finely chopped (adjust to your spice preference)', '2 tablespoons soy sauce', '1 tablespoon oyster sauce (optional)', '1 tablespoon cornstarch', '1 tablespoon vegetable oil', '1 teaspoon sesame oil', 'Cooked rice, for serving']
#
# 📊 Metrics:
#  {
#   "matched": 1,
#   "recall": 0.3333333333333333,
#   "precision": 0.08333333333333333,
#   "f1": 0.13333333333333333,
#   "pairs": [
#     [
#       "beef slices",
#       "1 lb beef slices sirloin or flank steak thinly sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 5/600
#
# 🔍 Prompt: I have shrimp, eggs, and rice. I want something quick like Cantonese fried rice.
# 🎯 Ground Truth (raw): shrimp, eggs, rice
# ✅ Parsed Ground Truth (list): ['shrimp', 'eggs', 'rice']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Quick Shrimp Fried Rice (Cantonese Style)",
#   "chosen_from": "User request",
#   "ingredients": [
#     "Cooked rice (day-old is best)",
#     "Shrimp, peeled and deveined",
#     "Eggs",
#     "Soy sauce",
#     "Cooking oil (vegetable or canola)",
#     "Scallions, chopped (optional)",
#     "Salt and white pepper to taste"
#   ],
#   "steps": [
#     "Whisk eggs with a pinch of salt and pepper.",
#     "Heat a wok or large skillet over high heat. Add a tablespoon of oil.",
#     "Pour in the eggs and quickly scramble until lightly cooked. Remove from the pan and set aside.",
#     "Add another tablespoon of oil to the pan. Stir-fry the shrimp until they turn pink and cooked through (about 2-3 minutes). Remove and set aside.",
#     "Add a little more oil if needed. Add the rice and break
#
# 🥬 Extracted Ingredients: ['Cooked rice (day-old is best)', 'Shrimp, peeled and deveined', 'Eggs', 'Soy sauce', 'Cooking oil (vegetable or canola)', 'Scallions, chopped (optional)', 'Salt and white pepper to taste']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "shrimp",
#       "shrimp peeled and deveined"
#     ],
#     [
#       "eggs",
#       "eggs"
#     ],
#     [
#       "rice",
#       "cooked rice day-old is best"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 6/600
#
# 🔍 Prompt: I have duck, honey, and five-spice powder. I want to make something aromatic and traditional.
# 🎯 Ground Truth (raw): duck, honey, five-spice powder
# ✅ Parsed Ground Truth (list): ['duck', 'honey', 'five-spice powder']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Honey-Glazed Five-Spice Duck",
#   "chosen_from": "Chinese Cuisine",
#   "ingredients": [
#     "1 Duck (about 4-5 lbs)",
#     "2 tbsp Honey",
#     "1 tbsp Five-Spice Powder",
#     "1 tbsp Soy Sauce",
#     "1 tbsp Rice Wine or Dry Sherry",
#     "1 tsp Sesame Oil",
#     "Salt and Black Pepper to taste",
#     "Water (for boiling)"
#   ],
#   "steps": [
#     "Rinse the duck inside and out, and pat it dry with paper towels.",
#     "Score the duck skin in a crosshatch pattern (not too deep, just through the skin) to help the fat render.",
#     "In a small bowl, combine honey, five-spice powder, soy sauce, rice wine (or sherry), and sesame oil. Mix well.",
#     "Season the duck inside and out with salt and pepper.",
#     "Rub the honey-five-spice mixture all over the duck, making sure to g
#
# 🥬 Extracted Ingredients: ['1 Duck (about 4-5 lbs)', '2 tbsp Honey', '1 tbsp Five-Spice Powder', '1 tbsp Soy Sauce', '1 tbsp Rice Wine or Dry Sherry', '1 tsp Sesame Oil', 'Salt and Black Pepper to taste', 'Water (for boiling)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.375,
#   "f1": 0.5454545454545454,
#   "pairs": [
#     [
#       "duck",
#       "1 duck about 4-5 lbs"
#     ],
#     [
#       "honey",
#       "2 tbsp honey"
#     ],
#     [
#       "five-spice powder",
#       "1 tbsp five-spice powder"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 7/600
#
# 🔍 Prompt: I have ground pork, napa cabbage, and garlic. I want a northern Chinese dumpling filling idea.
# 🎯 Ground Truth (raw): ground pork, napa cabbage, garlic
# ✅ Parsed Ground Truth (list): ['ground pork', 'napa cabbage', 'garlic']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Napa Cabbage and Pork Dumplings (Northern Chinese Style)",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 pound ground pork",
#     "1 pound napa cabbage, finely chopped and salted",
#     "4 cloves garlic, minced",
#     "2 tablespoons soy sauce",
#     "1 tablespoon sesame oil",
#     "1 teaspoon ground white pepper",
#     "1/2 teaspoon sugar",
#     "Dumpling wrappers (store-bought or homemade)",
#     "Water for sealing dumplings",
#     "Optional: Green onions, finely chopped, for garnish and/or filling"
#   ],
#   "steps": [
#     "Prepare the cabbage: Place the chopped napa cabbage in a colander and sprinkle with 1 teaspoon of salt. Let it sit for at least 30 minutes to release excess water. Then, rinse the cabbage thoroughly and squeeze out as much water as possibl
#
# 🥬 Extracted Ingredients: ['1 pound ground pork', '1 pound napa cabbage, finely chopped and salted', '4 cloves garlic, minced', '2 tablespoons soy sauce', '1 tablespoon sesame oil', '1 teaspoon ground white pepper', '1/2 teaspoon sugar', 'Dumpling wrappers (store-bought or homemade)', 'Water for sealing dumplings', 'Optional: Green onions, finely chopped, for garnish and/or filling']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3,
#   "f1": 0.4615384615384615,
#   "pairs": [
#     [
#       "ground pork",
#       "1 pound ground pork"
#     ],
#     [
#       "napa cabbage",
#       "1 pound napa cabbage finely chopped and salted"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 8/600
#
# 🔍 Prompt: I have noodles, sesame paste, and cucumber. I want a cold Sichuan-style noodle dish.
# 🎯 Ground Truth (raw): noodles, sesame paste, cucumber
# ✅ Parsed Ground Truth (list): ['noodles', 'sesame paste', 'cucumber']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cold Sesame Noodles with Cucumber (Sichuan Style)",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Noodles (preferably wheat noodles like Chinese noodles or spaghetti)",
#     "Sesame paste (tahini or Chinese sesame paste)",
#     "Cucumber",
#     "Soy sauce",
#     "Rice vinegar",
#     "Chili oil (with chili flakes, if available)",
#     "Garlic (minced)",
#     "Scallions (chopped)",
#     "Sesame oil",
#     "Sugar",
#     "Water (for thinning)"
#   ],
#   "steps": [
#     "Cook noodles according to package directions. Rinse under cold water to cool completely and drain well.",
#     "In a bowl, whisk together sesame paste, soy sauce, rice vinegar, chili oil (to taste), minced garlic, a small amount of sugar (start with a teaspoon and adjust to taste), and a drizzle of sesam
#
# 🥬 Extracted Ingredients: ['Noodles (preferably wheat noodles like Chinese noodles or spaghetti)', 'Sesame paste (tahini or Chinese sesame paste)', 'Cucumber', 'Soy sauce', 'Rice vinegar', 'Chili oil (with chili flakes, if available)', 'Garlic (minced)', 'Scallions (chopped)', 'Sesame oil', 'Sugar', 'Water (for thinning)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.2727272727272727,
#   "f1": 0.42857142857142855,
#   "pairs": [
#     [
#       "noodles",
#       "noodles preferably wheat noodles like chinese noodles or spaghetti"
#     ],
#     [
#       "sesame paste",
#       "sesame paste tahini or chinese sesame paste"
#     ],
#     [
#       "cucumber",
#       "cucumber"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 9/600
#
# 🔍 Prompt: I have fish fillet, chili peppers, and bean sprouts. I want to make boiled fish in spicy broth.
# 🎯 Ground Truth (raw): fish fillet, chili peppers, bean sprouts
# ✅ Parsed Ground Truth (list): ['fish fillet', 'chili peppers', 'bean sprouts']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Boiled Fish with Bean Sprouts",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Fish fillet",
#     "Chili peppers (amount according to spice preference)",
#     "Bean sprouts",
#     "Water or fish broth",
#     "Salt to taste",
#     "Soy sauce (optional)",
#     "Cooking oil"
#   ],
#   "steps": [
#     "Prepare the fish fillet: Rinse and pat dry. Cut into bite-sized pieces.",
#     "Prepare the chili peppers: Rinse and slice or chop chili peppers (remove seeds for less heat).",
#     "Sauté the chili peppers: Heat a small amount of cooking oil in a pot or wok over medium heat. Add the chili peppers and stir-fry for a minute until fragrant.",
#     "Add water/broth and seasonings: Pour in water or fish broth. Bring to a boil. Add salt and soy sauce (if using) to taste
#
# 🥬 Extracted Ingredients: ['Fish fillet', 'Chili peppers (amount according to spice preference)', 'Bean sprouts', 'Water or fish broth', 'Salt to taste', 'Soy sauce (optional)', 'Cooking oil']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "fish fillet",
#       "fish fillet"
#     ],
#     [
#       "chili peppers",
#       "chili peppers amount according to spice preference"
#     ],
#     [
#       "bean sprouts",
#       "bean sprouts"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 10/600
#
# 🔍 Prompt: I have tofu skin, peanuts, and vinegar. I want a refreshing cold appetizer.
# 🎯 Ground Truth (raw): tofu skin, peanuts, vinegar
# ✅ Parsed Ground Truth (list): ['tofu skin', 'peanuts', 'vinegar']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cold Tofu Skin Salad with Peanuts and Vinegar",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Tofu skin (yuba)",
#     "Peanuts",
#     "Rice vinegar (or other vinegar)",
#     "Soy sauce (optional)",
#     "Sesame oil (optional)",
#     "Chili oil (optional, for spice)",
#     "Sugar or sweetener (optional, to balance acidity)",
#     "Water (for blanching/soaking tofu skin)"
#   ],
#   "steps": [
#     "If using dried tofu skin, rehydrate it by soaking it in warm water until softened (about 15-30 minutes). If using fresh tofu skin, skip this step.",
#     "Blanch the tofu skin in boiling water for a minute or two to remove any excess oil and soften it further. Drain and rinse with cold water.",
#     "Cut the tofu skin into bite-sized pieces or strips.",
#     "If using, lig
#
# 🥬 Extracted Ingredients: ['Tofu skin (yuba)', 'Peanuts', 'Rice vinegar (or other vinegar)', 'Soy sauce (optional)', 'Sesame oil (optional)', 'Chili oil (optional, for spice)', 'Sugar or sweetener (optional, to balance acidity)', 'Water (for blanching/soaking tofu skin)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.375,
#   "f1": 0.5454545454545454,
#   "pairs": [
#     [
#       "tofu skin",
#       "tofu skin yuba"
#     ],
#     [
#       "peanuts",
#       "peanuts"
#     ],
#     [
#       "vinegar",
#       "rice vinegar or other vinegar"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 11/600
#
# 🔍 Prompt: I have ribs, soy sauce, and rock sugar. I want to make something sweet and savory like Hong Shao Pai Gu.
# 🎯 Ground Truth (raw): ribs, soy sauce, rock sugar
# ✅ Parsed Ground Truth (list): ['ribs', 'soy sauce', 'rock sugar']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simplified Hong Shao Pai Gu (Braised Ribs)",
#   "chosen_from": "User request and available ingredients",
#   "ingredients": [
#     "Ribs",
#     "Soy sauce",
#     "Rock sugar",
#     "Water (or chicken broth)",
#     "Cooking oil (optional)",
#     "Optional: Star anise, ginger, garlic, scallions, Shaoxing wine"
#   ],
#   "steps": [
#     "If using, lightly brown ribs in cooking oil over medium-high heat. Remove ribs and set aside.",
#     "Add rock sugar to the pan (if using oil) and melt it over medium heat, swirling occasionally. Be careful not to burn it.",
#     "Add ribs back to the pan (or add everything to a pot if not browning).",
#     "Pour in soy sauce and water (or broth) to cover the ribs. Add any optional ingredients like star anise, ginger, garlic, and/or Shaoxing wine.
#
# 🥬 Extracted Ingredients: ['Ribs', 'Soy sauce', 'Rock sugar', 'Water (or chicken broth)', 'Cooking oil (optional)', 'Optional: Star anise, ginger, garlic, scallions, Shaoxing wine']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.5,
#   "f1": 0.6666666666666666,
#   "pairs": [
#     [
#       "ribs",
#       "ribs"
#     ],
#     [
#       "soy sauce",
#       "soy sauce"
#     ],
#     [
#       "rock sugar",
#       "rock sugar"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 12/600
#
# 🔍 Prompt: I have eggs, tomatoes, and scallions. I want to make a simple Chinese comfort dish.
# 🎯 Ground Truth (raw): eggs, tomatoes, scallions
# ✅ Parsed Ground Truth (list): ['eggs', 'tomatoes', 'scallions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Tomato and Egg Stir-Fry (番茄炒蛋)",
#   "chosen_from": "Chinese cuisine",
#   "ingredients": [
#     "3 eggs",
#     "2 medium tomatoes, diced",
#     "2 scallions, sliced (separate white and green parts)",
#     "1 tablespoon cooking oil",
#     "1/2 teaspoon salt (or to taste)",
#     "1/4 teaspoon sugar",
#     "Pinch of white pepper (optional)"
#   ],
#   "steps": [
#     "Whisk the eggs with a pinch of salt and the white pepper (if using).",
#     "Heat the cooking oil in a wok or frying pan over medium-high heat.",
#     "Pour in the eggs and scramble until just cooked, about 15-20 seconds. Remove from pan and set aside.",
#     "Add the diced tomatoes to the pan and stir-fry for 1-2 minutes until softened.",
#     "Add the white parts of the scallions and stir-fry for 30 seconds.",
#     "Re
#
# 🥬 Extracted Ingredients: ['3 eggs', '2 medium tomatoes, diced', '2 scallions, sliced (separate white and green parts)', '1 tablespoon cooking oil', '1/2 teaspoon salt (or to taste)', '1/4 teaspoon sugar', 'Pinch of white pepper (optional)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "eggs",
#       "3 eggs"
#     ],
#     [
#       "tomatoes",
#       "2 medium tomatoes diced"
#     ],
#     [
#       "scallions",
#       "2 scallions sliced separate white and green parts"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 13/600
#
# 🔍 Prompt: I have chicken wings, soy sauce, and garlic. I want something sticky and flavorful.
# 🎯 Ground Truth (raw): chicken wings, soy sauce, garlic
# ✅ Parsed Ground Truth (list): ['chicken wings', 'soy sauce', 'garlic']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Garlic Soy Glazed Chicken Wings",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Chicken wings",
#     "Soy sauce",
#     "Garlic cloves (minced)",
#     "Vegetable oil (or other cooking oil)",
#     "Black pepper",
#     "Optional: Honey or brown sugar (for extra stickiness)"
#   ],
#   "steps": [
#     "Preheat oven to 400°F (200°C).",
#     "Pat the chicken wings dry with paper towels and season with black pepper.",
#     "In a bowl, combine minced garlic and soy sauce. If desired, add a spoonful or two of honey or brown sugar.",
#     "In a separate bowl, toss the chicken wings with a tablespoon of vegetable oil.",
#     "Arrange the wings in a single layer on a baking sheet lined with parchment paper.",
#     "Bake for 20 minutes.",
#     "Remove the wings from the oven and
#
# 🥬 Extracted Ingredients: ['Chicken wings', 'Soy sauce', 'Garlic cloves (minced)', 'Vegetable oil (or other cooking oil)', 'Black pepper', 'Optional: Honey or brown sugar (for extra stickiness)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.5,
#   "f1": 0.6666666666666666,
#   "pairs": [
#     [
#       "chicken wings",
#       "chicken wings"
#     ],
#     [
#       "soy sauce",
#       "soy sauce"
#     ],
#     [
#       "garlic",
#       "garlic cloves minced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 14/600
#
# 🔍 Prompt: I have lotus root, chili, and vinegar. I want a crispy, spicy side dish.
# 🎯 Ground Truth (raw): lotus root, chili, vinegar
# ✅ Parsed Ground Truth (list): ['lotus root', 'chili', 'vinegar']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Crispy Chili Lotus Root with Vinegar",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 large lotus root, peeled and thinly sliced",
#     "2-3 red chilies, thinly sliced (adjust to your spice preference)",
#     "2 tablespoons vinegar (rice vinegar recommended)",
#     "1 tablespoon soy sauce",
#     "1 teaspoon sugar",
#     "1/4 cup vegetable oil (for frying)",
#     "Salt, to taste",
#     "Cornstarch, for dusting"
#   ],
#   "steps": [
#     "Rinse the lotus root slices and pat them very dry with paper towels. This is crucial for crispiness.",
#     "Lightly dust the lotus root slices with cornstarch.",
#     "Heat the vegetable oil in a wok or deep frying pan over medium-high heat until it shimmers.",
#     "Carefully add the lotus root slices to the hot oil in batches, e
#
# 🥬 Extracted Ingredients: ['1 large lotus root, peeled and thinly sliced', '2-3 red chilies, thinly sliced (adjust to your spice preference)', '2 tablespoons vinegar (rice vinegar recommended)', '1 tablespoon soy sauce', '1 teaspoon sugar', '1/4 cup vegetable oil (for frying)', 'Salt, to taste', 'Cornstarch, for dusting']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.25,
#   "f1": 0.36363636363636365,
#   "pairs": [
#     [
#       "lotus root",
#       "1 large lotus root peeled and thinly sliced"
#     ],
#     [
#       "vinegar",
#       "2 tablespoons vinegar rice vinegar recommended"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 15/600
#
# 🔍 Prompt: I have beef brisket, daikon, and soy sauce. I want a slow-cooked Cantonese stew.
# 🎯 Ground Truth (raw): beef brisket, daikon, soy sauce
# ✅ Parsed Ground Truth (list): ['beef brisket', 'daikon', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cantonese Braised Beef Brisket with Daikon",
#   "chosen_from": "User's specified ingredients and desired style",
#   "ingredients": [
#     "2 lbs Beef Brisket, cut into large chunks",
#     "1 large Daikon radish, peeled and cut into 1-inch thick rounds",
#     "1/2 cup Soy Sauce",
#     "2 tbsp Cooking Oil (Vegetable or Canola)",
#     "2 cloves Garlic, minced",
#     "1 inch Ginger, minced",
#     "2 Star Anise",
#     "1 Cinnamon Stick",
#     "2 cups Water or Beef Broth",
#     "1 tbsp Sugar",
#     "1 tbsp Shaoxing Wine (optional)",
#     "Salt and White Pepper to taste"
#   ],
#   "steps": [
#     "Sear the beef brisket: Heat cooking oil in a large pot or Dutch oven over medium-high heat. Season the beef with salt and white pepper. Sear the brisket on all sides until browned.",
#     "Saut
#
# 🥬 Extracted Ingredients: ['2 lbs Beef Brisket, cut into large chunks', '1 large Daikon radish, peeled and cut into 1-inch thick rounds', '1/2 cup Soy Sauce', '2 tbsp Cooking Oil (Vegetable or Canola)', '2 cloves Garlic, minced', '1 inch Ginger, minced', '2 Star Anise', '1 Cinnamon Stick', '2 cups Water or Beef Broth', '1 tbsp Sugar', '1 tbsp Shaoxing Wine (optional)', 'Salt and White Pepper to taste']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.25,
#   "f1": 0.4,
#   "pairs": [
#     [
#       "beef brisket",
#       "2 lbs beef brisket cut into large chunks"
#     ],
#     [
#       "daikon",
#       "1 large daikon radish peeled and cut into 1-inch thick rounds"
#     ],
#     [
#       "soy sauce",
#       "1 2 cup soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 16/600
#
# 🔍 Prompt: I have spinach, garlic, and sesame oil. I want a light vegetable side dish.
# 🎯 Ground Truth (raw): spinach, garlic, sesame oil
# ✅ Parsed Ground Truth (list): ['spinach', 'garlic', 'sesame oil']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Sesame Garlic Spinach",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Spinach (fresh)",
#     "Garlic (minced)",
#     "Sesame oil",
#     "Salt",
#     "Pepper"
#   ],
#   "steps": [
#     "Wash and thoroughly dry the spinach.",
#     "Heat sesame oil in a pan over medium heat.",
#     "Add minced garlic and sauté for about 30 seconds, until fragrant (do not burn).",
#     "Add the spinach to the pan. Stir and cook until the spinach wilts, about 1-2 minutes.",
#     "Season with salt and pepper to taste.",
#     "Serve immediately."
#   ]
# }
# ```
#
# 🥬 Extracted Ingredients: ['Spinach (fresh)', 'Garlic (minced)', 'Sesame oil', 'Salt', 'Pepper']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.6,
#   "f1": 0.7499999999999999,
#   "pairs": [
#     [
#       "spinach",
#       "spinach fresh"
#     ],
#     [
#       "garlic",
#       "garlic minced"
#     ],
#     [
#       "sesame oil",
#       "sesame oil"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 17/600
#
# 🔍 Prompt: I have prawns, ginger, and green onions. I want to make a Chinese-style steamed seafood dish.
# 🎯 Ground Truth (raw): prawns, ginger, green onions
# ✅ Parsed Ground Truth (list): ['prawns', 'ginger', 'green onions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Steamed Ginger-Scallion Prawns",
#   "chosen_from": "User Request and Common Chinese Steaming Techniques",
#   "ingredients": [
#     "1 pound prawns, peeled and deveined (leave tails on for presentation)",
#     "2 tablespoons ginger, thinly sliced",
#     "4 green onions, cut into 2-inch lengths",
#     "2 tablespoons soy sauce",
#     "1 tablespoon sesame oil",
#     "1 teaspoon sugar",
#     "1/2 teaspoon white pepper",
#     "1 tablespoon cooking oil (vegetable or peanut)",
#     "Water for steaming"
#   ],
#   "steps": [
#     "Rinse prawns and pat dry.",
#     "Arrange ginger slices in a single layer on the bottom of a heat-proof plate.",
#     "Place the prawns over the ginger, arranging them in a single layer if possible.",
#     "Drizzle soy sauce, sesame oil, sugar, and white pepper o
#
# 🥬 Extracted Ingredients: ['1 pound prawns, peeled and deveined (leave tails on for presentation)', '2 tablespoons ginger, thinly sliced', '4 green onions, cut into 2-inch lengths', '2 tablespoons soy sauce', '1 tablespoon sesame oil', '1 teaspoon sugar', '1/2 teaspoon white pepper', '1 tablespoon cooking oil (vegetable or peanut)', 'Water for steaming']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "prawns",
#       "1 pound prawns peeled and deveined leave tails on for presentation"
#     ],
#     [
#       "ginger",
#       "2 tablespoons ginger thinly sliced"
#     ],
#     [
#       "green onions",
#       "4 green onions cut into 2-inch lengths"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 18/600
#
# 🔍 Prompt: I have tofu, minced pork, and chili bean paste. I want to make Mapo Tofu.
# 🎯 Ground Truth (raw): tofu, minced pork, chili bean paste
# ✅ Parsed Ground Truth (list): ['tofu', 'minced pork', 'chili bean paste']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Mapo Tofu",
#   "chosen_from": "Ingredients on hand",
#   "ingredients": [
#     "Firm tofu, cubed",
#     "Minced pork",
#     "Chili bean paste (doubanjiang)",
#     "Cooking oil",
#     "Water or broth",
#     "Cornstarch",
#     "Soy sauce",
#     "Sugar (optional)",
#     "White pepper (optional)",
#     "Green onions, chopped (for garnish)"
#   ],
#   "steps": [
#     "Heat oil in a wok or pan over medium-high heat. Stir-fry the minced pork until browned and cooked through.",
#     "Add chili bean paste and stir-fry for about 30 seconds until fragrant.",
#     "Pour in water or broth. Bring to a simmer.",
#     "Gently add the cubed tofu. Simmer for about 5 minutes, carefully stirring to avoid breaking the tofu.",
#     "In a small bowl, whisk together cornstarch and a small amount of water to
#
# 🥬 Extracted Ingredients: ['Firm tofu, cubed', 'Minced pork', 'Chili bean paste (doubanjiang)', 'Cooking oil', 'Water or broth', 'Cornstarch', 'Soy sauce', 'Sugar (optional)', 'White pepper (optional)', 'Green onions, chopped (for garnish)']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.2,
#   "f1": 0.30769230769230765,
#   "pairs": [
#     [
#       "tofu",
#       "firm tofu cubed"
#     ],
#     [
#       "minced pork",
#       "minced pork"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 19/600
#
# 🔍 Prompt: I have eggplant, garlic, and soy sauce. I want a spicy Sichuan-style stir-fry.
# 🎯 Ground Truth (raw): eggplant, garlic, soy sauce
# ✅ Parsed Ground Truth (list): ['eggplant', 'garlic', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Garlic Eggplant (Sichuan Style)",
#   "chosen_from": "A simplified version based on classic Sichuan flavors and ingredients",
#   "ingredients": [
#     "1 large eggplant, cut into 1-inch cubes",
#     "4 cloves garlic, minced",
#     "2 tablespoons soy sauce",
#     "1 tablespoon chili garlic sauce (or more, to taste)",
#     "1 tablespoon rice vinegar",
#     "1 teaspoon sugar",
#     "1 tablespoon vegetable oil",
#     "1/4 cup water or vegetable broth",
#     "Chopped scallions (for garnish, optional)"
#   ],
#   "steps": [
#     "Heat vegetable oil in a wok or large skillet over medium-high heat.",
#     "Add eggplant and stir-fry until softened and slightly browned, about 5-7 minutes. If the eggplant is browning too quickly and not softening, add a splash of water and cover for a
#
# 🥬 Extracted Ingredients: ['1 large eggplant, cut into 1-inch cubes', '4 cloves garlic, minced', '2 tablespoons soy sauce', '1 tablespoon chili garlic sauce (or more, to taste)', '1 tablespoon rice vinegar', '1 teaspoon sugar', '1 tablespoon vegetable oil', '1/4 cup water or vegetable broth', 'Chopped scallions (for garnish, optional)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "eggplant",
#       "1 large eggplant cut into 1-inch cubes"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ],
#     [
#       "soy sauce",
#       "2 tablespoons soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 20/600
#
# 🔍 Prompt: I have rice, chicken, and oyster sauce. I want something fast like Chinese fried rice.
# 🎯 Ground Truth (raw): rice, chicken, oyster sauce
# ✅ Parsed Ground Truth (list): ['rice', 'chicken', 'oyster sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Quick Chicken and Oyster Sauce Fried Rice",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Cooked Rice",
#     "Chicken (cooked and diced)",
#     "Oyster Sauce",
#     "Cooking Oil",
#     "Optional: Soy Sauce",
#     "Optional: Vegetables (e.g., peas, carrots, scallions)"
#   ],
#   "steps": [
#     "Heat cooking oil in a wok or large pan over medium-high heat.",
#     "Add chicken and any optional vegetables to the pan and stir-fry for 1-2 minutes until heated through.",
#     "Add the cooked rice to the pan and break it up with a spatula.",
#     "Pour oyster sauce (and soy sauce, if using) over the rice and chicken.",
#     "Stir-fry everything together for 2-3 minutes, ensuring the rice is coated and heated through.",
#     "Serve immediately."
#   ]
# }
# ```
#
# 🥬 Extracted Ingredients: ['Cooked Rice', 'Chicken (cooked and diced)', 'Oyster Sauce', 'Cooking Oil', 'Optional: Soy Sauce', 'Optional: Vegetables (e.g., peas, carrots, scallions)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.5,
#   "f1": 0.6666666666666666,
#   "pairs": [
#     [
#       "rice",
#       "cooked rice"
#     ],
#     [
#       "chicken",
#       "chicken cooked and diced"
#     ],
#     [
#       "oyster sauce",
#       "oyster sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 21/600
#
# 🔍 Prompt: I have pork belly, garlic, and soy sauce. I want to make something spicy and flavorful.
# 🎯 Ground Truth (raw): pork belly, garlic, soy sauce
# ✅ Parsed Ground Truth (list): ['pork belly', 'garlic', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Garlic Soy Pork Belly",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb pork belly, skin on or off, cut into 1-inch cubes",
#     "4 cloves garlic, minced",
#     "1/4 cup soy sauce",
#     "2 tablespoons chili garlic sauce (or sriracha)",
#     "1 tablespoon rice vinegar",
#     "1 tablespoon brown sugar",
#     "1 teaspoon sesame oil",
#     "1/4 teaspoon black pepper",
#     "Optional: 1-2 red chilies, thinly sliced (for extra heat)",
#     "Optional: Cooked rice, for serving",
#     "Optional: Green onions, chopped, for garnish"
#   ],
#   "steps": [
#     "In a bowl, whisk together soy sauce, chili garlic sauce (or sriracha), rice vinegar, brown sugar, sesame oil, and black pepper.",
#     "If using, slice the red chilies.",
#     "In a large skillet or wok, cook the
#
# 🥬 Extracted Ingredients: ['1 lb pork belly, skin on or off, cut into 1-inch cubes', '4 cloves garlic, minced', '1/4 cup soy sauce', '2 tablespoons chili garlic sauce (or sriracha)', '1 tablespoon rice vinegar', '1 tablespoon brown sugar', '1 teaspoon sesame oil', '1/4 teaspoon black pepper', 'Optional: 1-2 red chilies, thinly sliced (for extra heat)', 'Optional: Cooked rice, for serving', 'Optional: Green onions, chopped, for garnish']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.2727272727272727,
#   "f1": 0.42857142857142855,
#   "pairs": [
#     [
#       "pork belly",
#       "1 lb pork belly skin on or off cut into 1-inch cubes"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ],
#     [
#       "soy sauce",
#       "1 4 cup soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 22/600
#
# 🔍 Prompt: I have chicken breast, ginger, and scallions. I want to cook a simple Chinese stir-fry.
# 🎯 Ground Truth (raw): chicken breast, ginger, scallions
# ✅ Parsed Ground Truth (list): ['chicken breast', 'ginger', 'scallions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Ginger Scallion Chicken Stir-Fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb chicken breast, cut into bite-sized pieces",
#     "1 inch ginger, minced",
#     "3 scallions, sliced (separate whites and greens)",
#     "2 tablespoons soy sauce",
#     "1 tablespoon cornstarch",
#     "1 tablespoon vegetable oil",
#     "1 teaspoon sesame oil (optional)",
#     "Salt and pepper to taste",
#     "Cooked rice, for serving"
#   ],
#   "steps": [
#     "In a bowl, toss the chicken with cornstarch, a pinch of salt, and pepper.",
#     "Heat vegetable oil in a wok or large skillet over medium-high heat.",
#     "Add the chicken and stir-fry until browned and cooked through, about 5-7 minutes. Remove from the wok and set aside.",
#     "Add the ginger and scallion whites t
#
# 🥬 Extracted Ingredients: ['1 lb chicken breast, cut into bite-sized pieces', '1 inch ginger, minced', '3 scallions, sliced (separate whites and greens)', '2 tablespoons soy sauce', '1 tablespoon cornstarch', '1 tablespoon vegetable oil', '1 teaspoon sesame oil (optional)', 'Salt and pepper to taste', 'Cooked rice, for serving']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "chicken breast",
#       "1 lb chicken breast cut into bite-sized pieces"
#     ],
#     [
#       "ginger",
#       "1 inch ginger minced"
#     ],
#     [
#       "scallions",
#       "3 scallions sliced separate whites and greens"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 23/600
#
# 🔍 Prompt: I have tofu, chili bean paste, and ground pork. I want to make Mapo Tofu.
# 🎯 Ground Truth (raw): tofu, chili bean paste, ground pork
# ✅ Parsed Ground Truth (list): ['tofu', 'chili bean paste', 'ground pork']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Mapo Tofu",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 block firm or extra-firm tofu, cubed",
#     "1-2 tablespoons chili bean paste (doubanjiang)",
#     "1/2 pound ground pork",
#     "2 cloves garlic, minced",
#     "1 inch ginger, minced",
#     "1/4 cup chicken broth (or water)",
#     "1 tablespoon soy sauce",
#     "1 teaspoon sugar",
#     "1 teaspoon cornstarch",
#     "2 tablespoons cold water",
#     "2 tablespoons cooking oil",
#     "Green onions, chopped (for garnish)",
#     "White pepper (to taste)"
#   ],
#   "steps": [
#     "Press the tofu to remove excess water. Cube and set aside.",
#     "In a small bowl, mix the cornstarch with cold water to create a slurry. Set aside.",
#     "Heat cooking oil in a wok or large skillet over medium-high heat.",
#     "Add th
#
# 🥬 Extracted Ingredients: ['1 block firm or extra-firm tofu, cubed', '1-2 tablespoons chili bean paste (doubanjiang)', '1/2 pound ground pork', '2 cloves garlic, minced', '1 inch ginger, minced', '1/4 cup chicken broth (or water)', '1 tablespoon soy sauce', '1 teaspoon sugar', '1 teaspoon cornstarch', '2 tablespoons cold water', '2 tablespoons cooking oil', 'Green onions, chopped (for garnish)', 'White pepper (to taste)']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.15384615384615385,
#   "f1": 0.25,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm or extra-firm tofu cubed"
#     ],
#     [
#       "ground pork",
#       "1 2 pound ground pork"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 24/600
#
# 🔍 Prompt: I have beef slices, bell peppers, and onions. I want a quick stir-fry for dinner.
# 🎯 Ground Truth (raw): beef slices, bell peppers, onions
# ✅ Parsed Ground Truth (list): ['beef slices', 'bell peppers', 'onions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Quick Beef and Pepper Stir-fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb beef slices (sirloin or flank steak, thinly sliced)",
#     "1 large onion, sliced",
#     "2 bell peppers (any color), sliced",
#     "2 tablespoons soy sauce",
#     "1 tablespoon cornstarch",
#     "1 tablespoon vegetable oil",
#     "1 teaspoon sesame oil (optional)",
#     "1/2 teaspoon black pepper",
#     "Cooked rice, for serving"
#   ],
#   "steps": [
#     "In a small bowl, whisk together soy sauce and cornstarch.",
#     "Heat vegetable oil (and sesame oil, if using) in a large skillet or wok over high heat until smoking.",
#     "Add beef slices and stir-fry until browned (about 2-3 minutes). Remove beef from skillet and set aside.",
#     "Add onion and bell peppers to the skillet an
#
# 🥬 Extracted Ingredients: ['1 lb beef slices (sirloin or flank steak, thinly sliced)', '1 large onion, sliced', '2 bell peppers (any color), sliced', '2 tablespoons soy sauce', '1 tablespoon cornstarch', '1 tablespoon vegetable oil', '1 teaspoon sesame oil (optional)', '1/2 teaspoon black pepper', 'Cooked rice, for serving']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.2222222222222222,
#   "f1": 0.3333333333333333,
#   "pairs": [
#     [
#       "beef slices",
#       "1 lb beef slices sirloin or flank steak thinly sliced"
#     ],
#     [
#       "bell peppers",
#       "2 bell peppers any color sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 25/600
#
# 🔍 Prompt: I have shrimp, eggs, and rice. I want to make Cantonese-style fried rice.
# 🎯 Ground Truth (raw): shrimp, eggs, rice
# ✅ Parsed Ground Truth (list): ['shrimp', 'eggs', 'rice']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cantonese Shrimp Fried Rice",
#   "chosen_from": "User request",
#   "ingredients": [
#     "Cooked rice (day-old preferred)",
#     "Shrimp, peeled and deveined",
#     "Eggs",
#     "Soy sauce",
#     "Cooking oil (e.g., vegetable, peanut)",
#     "Scallions, chopped (green parts)",
#     "Salt",
#     "White pepper",
#     "Optional: Shaoxing wine (or dry sherry)"
#   ],
#   "steps": [
#     "Prepare the shrimp: If using frozen shrimp, thaw completely. Marinate the shrimp with a pinch of salt, white pepper, and a splash of Shaoxing wine (optional) for about 10 minutes.",
#     "Scramble the eggs: Crack the eggs into a bowl and lightly beat. Heat a small amount of oil in a wok or large frying pan over medium-high heat. Pour in the eggs and quickly scramble until just set. Remove the eggs f
#
# 🥬 Extracted Ingredients: ['Cooked rice (day-old preferred)', 'Shrimp, peeled and deveined', 'Eggs', 'Soy sauce', 'Cooking oil (e.g., vegetable, peanut)', 'Scallions, chopped (green parts)', 'Salt', 'White pepper', 'Optional: Shaoxing wine (or dry sherry)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "shrimp",
#       "shrimp peeled and deveined"
#     ],
#     [
#       "eggs",
#       "eggs"
#     ],
#     [
#       "rice",
#       "cooked rice day-old preferred"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 26/600
#
# 🔍 Prompt: I have duck, honey, and five-spice powder. I want to roast something aromatic and crispy.
# 🎯 Ground Truth (raw): duck, honey, five-spice powder
# ✅ Parsed Ground Truth (list): ['duck', 'honey', 'five-spice powder']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Honey-Five Spice Roasted Duck",
#   "chosen_from": "User's request",
#   "ingredients": [
#     "1 whole duck (about 4-5 pounds)",
#     "2 tablespoons honey",
#     "1 tablespoon five-spice powder",
#     "1 teaspoon salt",
#     "1/2 teaspoon black pepper",
#     "Optional: 1 orange, sliced (for aromatics)",
#     "Optional: 1 sprig fresh rosemary (for aromatics)"
#   ],
#   "steps": [
#     "Preheat oven to 400°F (200°C).",
#     "Remove giblets from the duck cavity. Rinse the duck inside and out and pat dry with paper towels.",
#     "In a small bowl, combine the honey, five-spice powder, salt, and pepper.",
#     "If using, place orange slices and rosemary sprig inside the duck cavity.",
#     "Rub the honey-spice mixture all over the duck, including under the skin of the breast and legs
#
# 🥬 Extracted Ingredients: ['1 whole duck (about 4-5 pounds)', '2 tablespoons honey', '1 tablespoon five-spice powder', '1 teaspoon salt', '1/2 teaspoon black pepper', 'Optional: 1 orange, sliced (for aromatics)', 'Optional: 1 sprig fresh rosemary (for aromatics)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "duck",
#       "1 whole duck about 4-5 pounds"
#     ],
#     [
#       "honey",
#       "2 tablespoons honey"
#     ],
#     [
#       "five-spice powder",
#       "1 tablespoon five-spice powder"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 27/600
#
# 🔍 Prompt: I have napa cabbage, ground pork, and soy sauce. I want to make dumpling fillings.
# 🎯 Ground Truth (raw): napa cabbage, ground pork, soy sauce
# ✅ Parsed Ground Truth (list): ['napa cabbage', 'ground pork', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Napa Cabbage and Pork Dumpling Filling",
#   "chosen_from": "Ingredients on hand",
#   "ingredients": [
#     "1 pound ground pork",
#     "1/2 medium head Napa cabbage, finely chopped",
#     "2 tablespoons soy sauce",
#     "Optional: 1 tablespoon minced ginger",
#     "Optional: 1 clove garlic, minced",
#     "Optional: 1 teaspoon sesame oil",
#     "Optional: Pinch of white pepper"
#   ],
#   "steps": [
#     "Place the chopped Napa cabbage in a bowl and sprinkle with salt. Let it sit for 15-20 minutes to draw out excess moisture. Then, squeeze out the water thoroughly using your hands or a clean kitchen towel.",
#     "In a mixing bowl, combine the ground pork, squeezed Napa cabbage, soy sauce, and any optional ingredients (ginger, garlic, sesame oil, and white pepper).",
#
#
# 🥬 Extracted Ingredients: ['1 pound ground pork', '1/2 medium head Napa cabbage, finely chopped', '2 tablespoons soy sauce', 'Optional: 1 tablespoon minced ginger', 'Optional: 1 clove garlic, minced', 'Optional: 1 teaspoon sesame oil', 'Optional: Pinch of white pepper']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "napa cabbage",
#       "1 2 medium head napa cabbage finely chopped"
#     ],
#     [
#       "ground pork",
#       "1 pound ground pork"
#     ],
#     [
#       "soy sauce",
#       "2 tablespoons soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 28/600
#
# 🔍 Prompt: I have noodles, sesame paste, and cucumber. I want to make cold Sichuan-style noodles.
# ...
#     "1 block extra-firm tofu, pressed",
#     "1 tbsp soy sauce",
#     "1 tbsp sesame oil",
#     "Optional: red pepper flakes",
#     "Optional: chopped green onions for garnish"
#   ],
#   "steps": [
#     "Press the tofu to remove excess water. Slice into 1/2 inch thick slabs or cubes.",
#     "Heat sesame oil in a non-stick pan over medium-high heat.",
#     "Add tofu to the pan, ensuring not to overcrowd it. Cook for 3-4 minutes per side, until golden brown and crispy.",
#     "Drizzle with soy sauce and sprinkle with red pepper flakes (if using).",
#     "Cook for another minute, allowing the sauce to caramelize slightly.",
#     "Garnish with green onions (if using) and serve immediately."
#   ]
# }
#
#
# 🥬 Extracted Ingredients: ['1 block extra-firm tofu, pressed', '1 tbsp soy sauce', '1 tbsp sesame oil', 'Optional: red pepper flakes', 'Optional: chopped green onions for garnish']
#
# 📊 Metrics:
#  {
#   "matched": 1,
#   "recall": 1.0,
#   "precision": 0.2,
#   "f1": 0.33333333333333337,
#   "pairs": [
#     [
#       "tofu",
#       "1 block extra-firm tofu pressed"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 592/600
#
# 🔍 Prompt: I have pork belly, sugar, and soy sauce. Want braised pork.
# 🎯 Ground Truth (raw): pork belly, sugar, soy sauce
# ✅ Parsed Ground Truth (list): ['pork belly', 'sugar', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Braised Pork Belly",
#   "chosen_from": "User request",
#   "ingredients": [
#     "Pork belly, cut into 1-inch cubes",
#     "Soy sauce",
#     "Sugar",
#     "Water"
#   ],
#   "steps": [
#     "In a pot or Dutch oven, combine pork belly, soy sauce, sugar, and enough water to mostly submerge the pork.",
#     "Bring the mixture to a boil, then reduce heat to a simmer.",
#     "Cover and simmer for at least 2 hours, or until the pork belly is tender and easily pierced with a fork.  Stir occasionally to prevent sticking.",
#     "If desired, remove the lid during the last 30 minutes of simmering to allow the sauce to thicken.",
#     "Serve hot, with rice and any other desired side dishes."
#   ]
# }
# ```
#
# 🥬 Extracted Ingredients: ['Pork belly, cut into 1-inch cubes', 'Soy sauce', 'Sugar', 'Water']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.75,
#   "f1": 0.8571428571428571,
#   "pairs": [
#     [
#       "pork belly",
#       "pork belly cut into 1-inch cubes"
#     ],
#     [
#       "sugar",
#       "sugar"
#     ],
#     [
#       "soy sauce",
#       "soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 593/600
#
# 🔍 Prompt: Got tofu, mushrooms, and chili. Want spicy stir-fry.
# 🎯 Ground Truth (raw): tofu, mushrooms, chili
# ✅ Parsed Ground Truth (list): ['tofu', 'mushrooms', 'chili']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Chili Garlic Tofu and Mushroom Stir-Fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 block firm or extra-firm tofu, pressed and cubed",
#     "8 oz mushrooms, sliced",
#     "1-2 red chilies, thinly sliced (adjust to your spice preference)",
#     "2 cloves garlic, minced",
#     "1 tbsp soy sauce (or tamari for gluten-free)",
#     "1 tbsp rice vinegar",
#     "1 tbsp sesame oil",
#     "1 tbsp cooking oil (vegetable, canola, etc.)",
#     "1 tsp cornstarch (optional, for thickening)",
#     "2 tbsp water (if using cornstarch)",
#     "Cooked rice, for serving",
#     "Green onions, chopped (for garnish, optional)"
#   ],
#   "steps": [
#     "Press the tofu to remove excess water. Cube the tofu and set aside.",
#     "Slice the mushrooms and chilies, mince the garlic.
#
# 🥬 Extracted Ingredients: ['1 block firm or extra-firm tofu, pressed and cubed', '8 oz mushrooms, sliced', '1-2 red chilies, thinly sliced (adjust to your spice preference)', '2 cloves garlic, minced', '1 tbsp soy sauce (or tamari for gluten-free)', '1 tbsp rice vinegar', '1 tbsp sesame oil', '1 tbsp cooking oil (vegetable, canola, etc.)', '1 tsp cornstarch (optional, for thickening)', '2 tbsp water (if using cornstarch)', 'Cooked rice, for serving', 'Green onions, chopped (for garnish, optional)']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.16666666666666666,
#   "f1": 0.26666666666666666,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm or extra-firm tofu pressed and cubed"
#     ],
#     [
#       "mushrooms",
#       "8 oz mushrooms sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 594/600
#
# 🔍 Prompt: I have chicken, soy sauce, and ginger. Want classic Chinese chicken.
# 🎯 Ground Truth (raw): chicken, soy sauce, ginger
# ✅ Parsed Ground Truth (list): ['chicken', 'soy sauce', 'ginger']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Soy Sauce Ginger Chicken",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1.5 lbs chicken pieces (thighs or drumsticks recommended)",
#     "1/4 cup soy sauce",
#     "1 tablespoon grated fresh ginger",
#     "1 tablespoon vegetable oil",
#     "2 cloves garlic, minced (optional)",
#     "1/4 cup water or chicken broth",
#     "1 tablespoon cornstarch (optional, for thickening)",
#     "1 teaspoon sugar (optional, balances flavors)",
#     "Green onions, chopped (for garnish, optional)"
#   ],
#   "steps": [
#     "In a bowl, combine soy sauce, grated ginger, and minced garlic (if using).",
#     "Heat oil in a large skillet or wok over medium-high heat.",
#     "Add chicken to the skillet and sear on both sides until lightly browned (about 2-3 minutes per side).",
#     "Pour th
#
# 🥬 Extracted Ingredients: ['1.5 lbs chicken pieces (thighs or drumsticks recommended)', '1/4 cup soy sauce', '1 tablespoon grated fresh ginger', '1 tablespoon vegetable oil', '2 cloves garlic, minced (optional)', '1/4 cup water or chicken broth', '1 tablespoon cornstarch (optional, for thickening)', '1 teaspoon sugar (optional, balances flavors)', 'Green onions, chopped (for garnish, optional)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "chicken",
#       "1 5 lbs chicken pieces thighs or drumsticks recommended"
#     ],
#     [
#       "soy sauce",
#       "1 4 cup soy sauce"
#     ],
#     [
#       "ginger",
#       "1 tablespoon grated fresh ginger"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 595/600
#
# 🔍 Prompt: Only tofu. Easy meal for one?
# 🎯 Ground Truth (raw): tofu
# ✅ Parsed Ground Truth (list): ['tofu']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Pan-Fried Tofu",
#   "chosen_from": "A need for a quick, easy, and only tofu meal.",
#   "ingredients": [
#     "1 block extra-firm tofu",
#     "1 tablespoon soy sauce",
#     "1 teaspoon sesame oil (optional)",
#     "Pinch of black pepper",
#     "Cooking spray or oil for pan-frying"
#   ],
#   "steps": [
#     "Press the tofu: Wrap the tofu block in paper towels and place a heavy object (like a book or cutting board) on top for at least 15 minutes to remove excess water.",
#     "Cut the tofu: Slice the pressed tofu into 1/2-inch thick slabs or cubes.",
#     "Marinate (optional): In a small bowl, whisk together soy sauce, sesame oil (if using), and pepper.  Gently toss the tofu in the marinade for a few minutes.",
#     "Pan-fry the tofu: Heat a non-stick pan over medium heat
#
# 🥬 Extracted Ingredients: ['1 block extra-firm tofu', '1 tablespoon soy sauce', '1 teaspoon sesame oil (optional)', 'Pinch of black pepper', 'Cooking spray or oil for pan-frying']
#
# 📊 Metrics:
#  {
#   "matched": 1,
#   "recall": 1.0,
#   "precision": 0.2,
#   "f1": 0.33333333333333337,
#   "pairs": [
#     [
#       "tofu",
#       "1 block extra-firm tofu"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 596/600
#
# 🔍 Prompt: I’ve got beef, chili, and garlic. Want hot stir-fry.
# 🎯 Ground Truth (raw): beef, chili, garlic
# ✅ Parsed Ground Truth (list): ['beef', 'chili', 'garlic']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Beef & Chili Garlic Stir-Fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb beef, thinly sliced",
#     "2-3 cloves garlic, minced",
#     "1-2 red chilies, thinly sliced (adjust to your spice preference)",
#     "2 tbsp soy sauce",
#     "1 tbsp oyster sauce (optional)",
#     "1 tbsp cornstarch",
#     "1 tbsp vegetable oil",
#     "1/2 cup chopped onion (optional)",
#     "Cooked rice or noodles for serving"
#   ],
#   "steps": [
#     "In a small bowl, whisk together soy sauce, oyster sauce (if using), and cornstarch.",
#     "Heat vegetable oil in a wok or large skillet over high heat.",
#     "Add beef and stir-fry until browned (about 2-3 minutes). Remove beef from wok and set aside.",
#     "If using, add onion to the wok and stir-fry until softened (about 1
#
# 🥬 Extracted Ingredients: ['1 lb beef, thinly sliced', '2-3 cloves garlic, minced', '1-2 red chilies, thinly sliced (adjust to your spice preference)', '2 tbsp soy sauce', '1 tbsp oyster sauce (optional)', '1 tbsp cornstarch', '1 tbsp vegetable oil', '1/2 cup chopped onion (optional)', 'Cooked rice or noodles for serving']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.2222222222222222,
#   "f1": 0.3333333333333333,
#   "pairs": [
#     [
#       "beef",
#       "1 lb beef thinly sliced"
#     ],
#     [
#       "garlic",
#       "2-3 cloves garlic minced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 597/600
#
# 🔍 Prompt: Got tofu, mushrooms, and soy sauce. Want vegetarian dish.
# 🎯 Ground Truth (raw): tofu, mushrooms, soy sauce
# ✅ Parsed Ground Truth (list): ['tofu', 'mushrooms', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Soy-Glazed Tofu and Mushroom Stir-fry",
#   "chosen_from": "Ingredients on hand",
#   "ingredients": [
#     "1 block firm tofu, pressed and cubed",
#     "8 oz mushrooms, sliced",
#     "1/4 cup soy sauce",
#     "1 tbsp vegetable oil",
#     "1 clove garlic, minced",
#     "1 inch ginger, grated",
#     "1 tbsp cornstarch",
#     "2 tbsp water",
#     "Cooked rice, for serving",
#     "Optional: sesame seeds and chopped scallions for garnish"
#   ],
#   "steps": [
#     "Press the tofu to remove excess water. Cube the tofu.",
#     "Heat vegetable oil in a large skillet or wok over medium-high heat.",
#     "Add the tofu and stir-fry until golden brown and crispy, about 5-7 minutes. Remove from skillet and set aside.",
#     "Add the sliced mushrooms to the skillet and stir-fry until softened an
#
# 🥬 Extracted Ingredients: ['1 block firm tofu, pressed and cubed', '8 oz mushrooms, sliced', '1/4 cup soy sauce', '1 tbsp vegetable oil', '1 clove garlic, minced', '1 inch ginger, grated', '1 tbsp cornstarch', '2 tbsp water', 'Cooked rice, for serving', 'Optional: sesame seeds and chopped scallions for garnish']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3,
#   "f1": 0.4615384615384615,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm tofu pressed and cubed"
#     ],
#     [
#       "mushrooms",
#       "8 oz mushrooms sliced"
#     ],
#     [
#       "soy sauce",
#       "1 4 cup soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 598/600
#
# 🔍 Prompt: I have shrimp, garlic, and chili oil. Want spicy seafood dish.
# 🎯 Ground Truth (raw): shrimp, garlic, chili oil
# ✅ Parsed Ground Truth (list): ['shrimp', 'garlic', 'chili oil']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Garlic Shrimp",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 pound shrimp, peeled and deveined",
#     "4 cloves garlic, minced",
#     "2-3 tablespoons chili oil (adjust to your spice preference)",
#     "1 tablespoon olive oil",
#     "Salt and pepper to taste",
#     "Optional: 1 tablespoon soy sauce or fish sauce",
#     "Optional: Fresh cilantro or green onions for garnish"
#   ],
#   "steps": [
#     "Heat olive oil and chili oil in a large skillet or wok over medium-high heat.",
#     "Add minced garlic and cook for about 30 seconds, until fragrant, being careful not to burn it.",
#     "Add shrimp to the skillet. Season with salt and pepper. If using, add soy sauce or fish sauce.",
#     "Cook shrimp, stirring frequently, until they turn pink and opaque, abo
#
# 🥬 Extracted Ingredients: ['1 pound shrimp, peeled and deveined', '4 cloves garlic, minced', '2-3 tablespoons chili oil (adjust to your spice preference)', '1 tablespoon olive oil', 'Salt and pepper to taste', 'Optional: 1 tablespoon soy sauce or fish sauce', 'Optional: Fresh cilantro or green onions for garnish']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "shrimp",
#       "1 pound shrimp peeled and deveined"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ],
#     [
#       "chili oil",
#       "2-3 tablespoons chili oil adjust to your spice preference"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 599/600
#
# 🔍 Prompt: Cooking for myself. Have tofu and soy sauce.
# 🎯 Ground Truth (raw): tofu, soy sauce
# ✅ Parsed Ground Truth (list): ['tofu', 'soy sauce']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Soy Sauce Tofu",
#   "chosen_from": "Ingredients available",
#   "ingredients": [
#     "1 block firm or extra-firm tofu",
#     "Soy sauce"
#   ],
#   "steps": [
#     "Press the tofu to remove excess water. You can do this by wrapping it in paper towels and placing a heavy object on top for 15-30 minutes.",
#     "Cut the tofu into cubes or slices.",
#     "Heat a lightly oiled pan over medium heat.",
#     "Add the tofu to the pan and cook until golden brown on all sides.",
#     "Drizzle generously with soy sauce and cook for another minute or two, until the sauce has slightly caramelized and coated the tofu.",
#     "Serve immediately."
#   ]
# }
# ```
#
# 🥬 Extracted Ingredients: ['1 block firm or extra-firm tofu', 'Soy sauce']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 1.0,
#   "precision": 1.0,
#   "f1": 1.0,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm or extra-firm tofu"
#     ],
#     [
#       "soy sauce",
#       "soy sauce"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 600/600
#
# 🔍 Prompt: Got pork ribs, soy sauce, and sugar. Want braised ribs.
# 🎯 Ground Truth (raw): pork ribs, soy sauce, sugar
# ✅ Parsed Ground Truth (list): ['pork ribs', 'soy sauce', 'sugar']
# 📦 Retrieved 3 candidates from Chroma
# Evaluating recipes: 100%|██████████| 12/12 [22:18<00:00, 111.52s/it]
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Simple Soy-Braised Pork Ribs",
#   "chosen_from": "User request",
#   "ingredients": [
#     "Pork ribs",
#     "Soy sauce",
#     "Sugar",
#     "Water (or chicken broth, optional)",
#     "Garlic cloves (optional)",
#     "Ginger, peeled and sliced (optional)",
#     "Star anise (optional)"
#   ],
#   "steps": [
#     "Rinse the pork ribs and pat them dry.",
#     "If desired, brown the ribs in a pan over medium-high heat with a little oil until lightly browned on all sides. This adds flavor, but is optional.",
#     "In a pot or Dutch oven, combine the ribs, soy sauce, sugar, and enough water (or broth) to mostly submerge the ribs. If using, add garlic, ginger, and star anise.",
#     "Bring the liquid to a simmer over medium heat.  ",
#     "Reduce the heat to low, cover the pot, and let t
#
# 🥬 Extracted Ingredients: ['Pork ribs', 'Soy sauce', 'Sugar', 'Water (or chicken broth, optional)', 'Garlic cloves (optional)', 'Ginger, peeled and sliced (optional)', 'Star anise (optional)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "pork ribs",
#       "pork ribs"
#     ],
#     [
#       "soy sauce",
#       "soy sauce"
#     ],
#     [
#       "sugar",
#       "sugar"
#     ]
#   ]
# }
#
# ✅ 所有指标已保存到: outputs/baseline\metrics_results.csv

# %%
results_df.to_csv(results_path, index=False, encoding="utf-8-sig")
