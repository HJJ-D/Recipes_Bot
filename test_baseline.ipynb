# %%
# ==========================================================
# 🍳 Full Self-contained RAG + Gemini + Recall Test Script
# ==========================================================

import os, re, json
from typing import List, Dict, Any, Tuple
import chromadb
from chromadb.utils import embedding_functions
import google.generativeai as genai
from difflib import SequenceMatcher
import pandas as pd
from tqdm import tqdm
import re
import ast

# ==========================================================
# 🔧 Configuration
# ==========================================================
DB_PATH = "vector_new_db/recipes"   # ✅ 你的数据库路径
MODEL_NAME = "gemini-2.0-flash-lite"
GENAI_API_KEY = os.getenv('GENAI_API_KEY') # ⚠️ 这里填你的 Google API Key

TOP_K_DEFAULT = 3
OUTPUT_DIR = "/content/evaluation_results"
os.makedirs(OUTPUT_DIR, exist_ok=True)

# ==========================================================
# 🧠 Chroma + Embedder
# ==========================================================
chroma_client = chromadb.PersistentClient(path=DB_PATH)
embedder = embedding_functions.SentenceTransformerEmbeddingFunction(
    model_name="BAAI/bge-m3"
)
collection = chroma_client.get_collection("recipes")

# ==========================================================
# 🤖 Gemini init
# ==========================================================
genai.configure(api_key=GENAI_API_KEY)
model = genai.GenerativeModel(MODEL_NAME)

# ==========================================================
# 🧂 Ingredient Normalization + Matching
# ==========================================================
TOKEN_CLEAN_RE = re.compile(r"[^a-zA-Z0-9\s\-]")
STOP_TOKENS = {"fresh","dried","chopped","sliced","minced","ground","crushed",
    "thinly","thick","thickly","small","medium","large","whole","skinless",
    "boneless","lean","extra","optional","to","taste","of","and","or"}

CANONICAL_MAP = {
    "chicken thigh":"chicken","chicken thighs":"chicken","chicken breast":"chicken",
    "beef rib":"beef ribs","beef ribs":"beef ribs","pork belly":"pork belly",
    "pork ribs":"pork ribs","pork":"pork",
    "tofu":"tofu","tofu skin":"yuba","bean curd skin":"yuba","yuba":"yuba",
    "garlic":"garlic","ginger":"ginger","chili oil":"chili oil",
    "soy sauce":"soy sauce","doubanjiang":"doubanjiang"
}
CONFLICTS = {("tofu","yuba"),("yuba","tofu")}

def _normalize(s:str)->str:
    s = s.lower().strip()
    s = TOKEN_CLEAN_RE.sub(" ", s)
    return re.sub(r"\s+"," ",s).strip()

def _canonicalize(s:str)->str:
    s_norm=_normalize(s)
    for k in sorted(CANONICAL_MAP,key=len,reverse=True):
        if re.search(rf"(?<![a-z0-9]){re.escape(k)}(?![a-z0-9])",s_norm):
            return CANONICAL_MAP[k]
    return s_norm

def _is_conflict(a,b): return (a,b) in CONFLICTS
def _similar(a,b): return SequenceMatcher(None,a,b).ratio()

def match_ing(a,b,th=0.88):
    a,b=_canonicalize(a),_canonicalize(b)
    if _is_conflict(a,b): return False
    if a==b: return True
    if re.search(rf"(?<![a-z0-9]){re.escape(a)}(?![a-z0-9])",b) or re.search(rf"(?<![a-z0-9]){re.escape(b)}(?![a-z0-9])",a):
        return True
    return _similar(a,b)>=th

# ==========================================================
# 🍲 RecipeModelEvaluator
# ==========================================================
class RecipeModelEvaluator:
    def __init__(self,collection,embedder,model,top_k:int=3):
        self.collection=collection
        self.embedder=embedder
        self.model=model
        self.top_k=top_k

    def _retrieve_recipes(self,query:str)->List[Dict[str,Any]]:
        emb=self.embedder([query])[0]
        res=self.collection.query(query_embeddings=[emb],n_results=self.top_k)
        docs=res.get("documents",[[]])[0]
        metas=res.get("metadatas",[[]])[0]
        out=[]
        for i in range(min(len(docs),self.top_k)):
            m=metas[i]
            out.append({
                "name":m.get("Recipes_name",""),
                "flavor":m.get("Flavor",""),
                "difficulty":m.get("Difficulty",""),
                "time":m.get("Estimated Cooking Time",""),
                "doc":docs[i]
            })
        return out

    def _build_prompt(self,query:str,cands:List[Dict[str,Any]])->str:
        blocks=[]
        for i,c in enumerate(cands,1):
            blocks.append(f"[Candidate {i}]\nName:{c['name']}\nFlavor:{c['flavor']}\nContent:\n{c['doc']}")
        schema={
            "recipe_name":"string",
            "chosen_from":"string",
            "ingredients":["string","..."],
            "steps":["string","..."],
        }
        return f"""
User request:
{query}

Output exactly ONE JSON object following this schema:
{json.dumps(schema,indent=2)}
"""

    def generate_recipe(self,prompt:str)->str:
        cands=self._retrieve_recipes(prompt)
        print(f"📦 Retrieved {len(cands)} candidates from Chroma")
        llm_prompt=self._build_prompt(prompt,cands)
        try:
            resp=self.model.generate_content(llm_prompt)
            return resp.text
        except Exception as e:
            return json.dumps({"recipe_name":"ERROR","chosen_from":"ERROR","ingredients":[],"steps":[],"reasoning":str(e)})

    def parse_json(self,text:str)->Dict[str,Any]:
        try: return json.loads(text)
        except: pass
        m=re.search(r"(\{.*\})",text,flags=re.DOTALL)
        if m:
            try: return json.loads(m.group(1))
            except: pass
        return {"recipe_name":"NO_MATCH","chosen_from":"NO_MATCH","ingredients":[],"steps":[],"reasoning":""}

    def calc_recall(self,user_ings:List[str],gen_ings:List[str])->Dict[str,Any]:
        u=[_normalize(x) for x in user_ings]
        g=[_normalize(x) for x in gen_ings]
        match=[]
        mg=set()
        for ui in u:
            for j,gi in enumerate(g):
                if j in mg: continue
                if match_ing(ui,gi):
                    match.append((ui,gi)); mg.add(j); break
        r=len(match)/len(u) if u else 0
        p=len(match)/len(g) if g else 0
        f=2*r*p/(r+p) if (r+p)>0 else 0
        return {"matched":len(match),"recall":r,"precision":p,"f1":f,"pairs":match}

# ==========================================================
# 🧪 Test: Single Prompt Recall
# ==========================================================
model_eval = RecipeModelEvaluator(collection,embedder,model)


# ===== 基础设置 =====
df = pd.read_csv("recipes_prompt_label.csv")
df = df.iloc[0:10]  # 仅测试前 10 条样本
BATCH_SIZE = 50
OUTPUT_DIR = "outputs/baseline"
os.makedirs(OUTPUT_DIR, exist_ok=True)

all_results = []  # 用于存放每条样本的指标数据

# ===== 主循环 =====
for i in tqdm(range(0, len(df), BATCH_SIZE), desc="Evaluating recipes"):
    batch = df.iloc[i:i + BATCH_SIZE]
    docs = batch["prompt"].tolist()
    ids = batch["ingredients/label"].tolist()

    for j, (prompt, gold_ings_raw) in enumerate(zip(docs, ids)):
        print("\n" + "=" * 80)
        print(f"🧩 Sample {i + j + 1}/{len(df)}")

        print("\n🔍 Prompt:", prompt)
        print("🎯 Ground Truth (raw):", gold_ings_raw)

        # 1️⃣ 将 gold_ings_raw 转成真正的 list
        if isinstance(gold_ings_raw, str):
            try:
                # 尝试把 "['salt','oil']" 转成 ['salt','oil']
                gold_ings = ast.literal_eval(gold_ings_raw)
                if not isinstance(gold_ings, list):
                    gold_ings = [gold_ings]
            except Exception:
                # 如果只是用逗号隔开的字符串
                gold_ings = [x.strip() for x in gold_ings_raw.split(",") if x.strip()]
        else:
            # 其他情况（如本身是 list/Series）
            gold_ings = list(gold_ings_raw) if not isinstance(gold_ings_raw, list) else gold_ings_raw

        print("✅ Parsed Ground Truth (list):", gold_ings)

        # 2️⃣ 生成模型输出
        raw_out = model_eval.generate_recipe(prompt)
        print("\n💬 Gemini Raw Output:\n", raw_out[:800])

        # 3️⃣ 解析模型输出
        parsed = model_eval.parse_json(raw_out)
        gen_ings = parsed.get("ingredients", [])
        print("\n🥬 Extracted Ingredients:", gen_ings)

        # 4️⃣ 计算指标
        metrics = model_eval.calc_recall(gold_ings, gen_ings)
        print("\n📊 Metrics:\n", json.dumps(metrics, indent=2, ensure_ascii=False))

        # 5️⃣ 保存结果（仅指标部分）
        metrics_row = {"id": i + j + 1, "prompt": prompt}
        metrics_row.update(metrics)
        metrics_row["raw_output"] = raw_out
        all_results.append(metrics_row)

# ===== 汇总保存到 CSV =====
results_df = pd.DataFrame(all_results)
results_path = os.path.join(OUTPUT_DIR, "metrics_results.csv")
results_df.to_csv(results_path, index=False, encoding="utf-8-sig")

print(f"\n✅ 所有指标已保存到: {results_path}")
# Out:
# d:\Anaconda3\envs\lab-mushroom-chatbot\Lib\site-packages\requests\__init__.py:86: RequestsDependencyWarning: Unable to find acceptable character detection dependency (chardet or charset_normalizer).
#   warnings.warn(
# Evaluating recipes:   0%|          | 0/1 [00:00<?, ?it/s]
# ================================================================================
# 🧩 Sample 1/10
#
# 🔍 Prompt: I have pork belly, garlic, and chili oil. I want to make something spicy and Sichuan-style.
# 🎯 Ground Truth (raw): pork belly, garlic, chili oil
# ✅ Parsed Ground Truth (list): ['pork belly', 'garlic', 'chili oil']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Sichuan Pork Belly with Garlic and Chili Oil",
#   "chosen_from": "User Request and Common Sichuan Recipes",
#   "ingredients": [
#     "500g pork belly, skin on",
#     "4 cloves garlic, minced",
#     "2 tablespoons chili oil",
#     "1 tablespoon light soy sauce",
#     "1 tablespoon dark soy sauce",
#     "1 teaspoon Sichuan peppercorns, toasted and ground",
#     "1/2 teaspoon white sugar",
#     "1/4 cup water",
#     "1 tablespoon vegetable oil",
#     "Green onions, chopped (for garnish)",
#     "Cooked rice, for serving"
#   ],
#   "steps": [
#     "Cut the pork belly into 1-inch thick slices.",
#     "Blanch the pork belly in boiling water for 5 minutes. Drain and rinse with cold water.",
#     "In a small bowl, combine light soy sauce, dark soy sauce, ground Sichuan peppercorns, a
#
# 🥬 Extracted Ingredients: ['500g pork belly, skin on', '4 cloves garlic, minced', '2 tablespoons chili oil', '1 tablespoon light soy sauce', '1 tablespoon dark soy sauce', '1 teaspoon Sichuan peppercorns, toasted and ground', '1/2 teaspoon white sugar', '1/4 cup water', '1 tablespoon vegetable oil', 'Green onions, chopped (for garnish)', 'Cooked rice, for serving']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.2727272727272727,
#   "f1": 0.42857142857142855,
#   "pairs": [
#     [
#       "pork belly",
#       "500g pork belly skin on"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ],
#     [
#       "chili oil",
#       "2 tablespoons chili oil"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 2/10
#
# 🔍 Prompt: I have chicken thighs, soy sauce, and ginger. I want a simple Chinese home-style dish.
# 🎯 Ground Truth (raw): chicken thighs, soy sauce, ginger
# ✅ Parsed Ground Truth (list): ['chicken thighs', 'soy sauce', 'ginger']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Soy Sauce Ginger Chicken Thighs",
#   "chosen_from": "Ingredients available",
#   "ingredients": [
#     "4 chicken thighs",
#     "1/4 cup soy sauce",
#     "1 tablespoon grated fresh ginger",
#     "1 tablespoon vegetable oil",
#     "1 clove garlic, minced (optional)",
#     "Cooked rice, for serving",
#     "Scallions, sliced (optional, for garnish)"
#   ],
#   "steps": [
#     "Pat the chicken thighs dry with paper towels.",
#     "In a bowl, combine the soy sauce, grated ginger, and minced garlic (if using).",
#     "Marinate the chicken thighs in the soy sauce mixture for at least 20 minutes (or up to a few hours in the refrigerator).",
#     "Heat the vegetable oil in a skillet or wok over medium-high heat.",
#     "Remove the chicken thighs from the marinade (discard the marinade).",
#
#
# 🥬 Extracted Ingredients: ['4 chicken thighs', '1/4 cup soy sauce', '1 tablespoon grated fresh ginger', '1 tablespoon vegetable oil', '1 clove garlic, minced (optional)', 'Cooked rice, for serving', 'Scallions, sliced (optional, for garnish)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.42857142857142855,
#   "f1": 0.6,
#   "pairs": [
#     [
#       "chicken thighs",
#       "4 chicken thighs"
#     ],
#     [
#       "soy sauce",
#       "1 4 cup soy sauce"
#     ],
#     [
#       "ginger",
#       "1 tablespoon grated fresh ginger"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 3/10
#
# 🔍 Prompt: I have tofu, bok choy, and mushrooms. I want something light and vegetarian like a soup.
# 🎯 Ground Truth (raw): tofu, bok choy, mushrooms
# ✅ Parsed Ground Truth (list): ['tofu', 'bok choy', 'mushrooms']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Tofu, Bok Choy, and Mushroom Soup",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 block firm tofu, pressed and cubed",
#     "1 bunch bok choy, chopped",
#     "8 oz mushrooms, sliced",
#     "4 cups vegetable broth",
#     "1 tbsp soy sauce",
#     "1 tsp sesame oil",
#     "1 inch ginger, minced",
#     "2 cloves garlic, minced",
#     "Green onions, chopped (for garnish - optional)",
#     "Salt and pepper to taste"
#   ],
#   "steps": [
#     "In a pot or large saucepan, heat sesame oil over medium heat.",
#     "Add ginger and garlic, and sauté for about 30 seconds until fragrant.",
#     "Add mushrooms and cook until softened, about 5 minutes.",
#     "Pour in vegetable broth and bring to a simmer.",
#     "Add tofu and bok choy to the soup.",
#     "Season with soy sauce, sal
#
# 🥬 Extracted Ingredients: ['1 block firm tofu, pressed and cubed', '1 bunch bok choy, chopped', '8 oz mushrooms, sliced', '4 cups vegetable broth', '1 tbsp soy sauce', '1 tsp sesame oil', '1 inch ginger, minced', '2 cloves garlic, minced', 'Green onions, chopped (for garnish - optional)', 'Salt and pepper to taste']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3,
#   "f1": 0.4615384615384615,
#   "pairs": [
#     [
#       "tofu",
#       "1 block firm tofu pressed and cubed"
#     ],
#     [
#       "bok choy",
#       "1 bunch bok choy chopped"
#     ],
#     [
#       "mushrooms",
#       "8 oz mushrooms sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 4/10
#
# 🔍 Prompt: I have beef slices, bell peppers, and onions. I want to make a stir-fry that's slightly spicy.
# 🎯 Ground Truth (raw): beef slices, bell peppers, onions
# ✅ Parsed Ground Truth (list): ['beef slices', 'bell peppers', 'onions']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Beef and Pepper Stir-fry",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "1 lb beef slices (sirloin or flank steak)",
#     "1 large onion, sliced",
#     "2 bell peppers (any color), sliced",
#     "2 tablespoons soy sauce",
#     "1 tablespoon cornstarch",
#     "1 tablespoon sesame oil",
#     "1 tablespoon vegetable oil",
#     "1-2 teaspoons red pepper flakes (adjust to your spice preference)",
#     "2 cloves garlic, minced",
#     "1 inch ginger, grated",
#     "Cooked rice, for serving (optional)"
#   ],
#   "steps": [
#     "In a bowl, combine the beef slices, 1 tablespoon soy sauce, and cornstarch. Toss to coat and set aside.",
#     "Heat the vegetable oil in a wok or large skillet over high heat until shimmering.",
#     "Add the beef and stir-fry quickly until br
#
# 🥬 Extracted Ingredients: ['1 lb beef slices (sirloin or flank steak)', '1 large onion, sliced', '2 bell peppers (any color), sliced', '2 tablespoons soy sauce', '1 tablespoon cornstarch', '1 tablespoon sesame oil', '1 tablespoon vegetable oil', '1-2 teaspoons red pepper flakes (adjust to your spice preference)', '2 cloves garlic, minced', '1 inch ginger, grated', 'Cooked rice, for serving (optional)']
#
# 📊 Metrics:
#  {
#   "matched": 2,
#   "recall": 0.6666666666666666,
#   "precision": 0.18181818181818182,
#   "f1": 0.28571428571428575,
#   "pairs": [
#     [
#       "beef slices",
#       "1 lb beef slices sirloin or flank steak"
#     ],
#     [
#       "bell peppers",
#       "2 bell peppers any color sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 5/10
#
# 🔍 Prompt: I have shrimp, eggs, and rice. I want something quick like Cantonese fried rice.
# 🎯 Ground Truth (raw): shrimp, eggs, rice
# ✅ Parsed Ground Truth (list): ['shrimp', 'eggs', 'rice']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Quick Shrimp Fried Rice (Cantonese Style)",
#   "chosen_from": "User request for quick Cantonese fried rice with shrimp, eggs, and rice.",
#   "ingredients": [
#     "2 cups cooked rice (day-old is best)",
#     "1/2 lb shrimp, peeled and deveined",
#     "2 eggs",
#     "2 tbsp soy sauce",
#     "1 tbsp oyster sauce (optional)",
#     "1 tbsp vegetable oil",
#     "1 clove garlic, minced",
#     "1/4 cup chopped scallions",
#     "Salt and white pepper to taste"
#   ],
#   "steps": [
#     "Heat vegetable oil in a wok or large skillet over medium-high heat.",
#     "Scramble eggs in the pan until cooked; remove and set aside.",
#     "Add shrimp to the wok and cook until pink and opaque.",
#     "Add garlic and cook until fragrant (about 30 seconds).",
#     "Add rice to the wok and break it up w
#
# 🥬 Extracted Ingredients: ['2 cups cooked rice (day-old is best)', '1/2 lb shrimp, peeled and deveined', '2 eggs', '2 tbsp soy sauce', '1 tbsp oyster sauce (optional)', '1 tbsp vegetable oil', '1 clove garlic, minced', '1/4 cup chopped scallions', 'Salt and white pepper to taste']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "shrimp",
#       "1 2 lb shrimp peeled and deveined"
#     ],
#     [
#       "eggs",
#       "2 eggs"
#     ],
#     [
#       "rice",
#       "2 cups cooked rice day-old is best"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 6/10
#
# 🔍 Prompt: I have duck, honey, and five-spice powder. I want to make something aromatic and traditional.
# 🎯 Ground Truth (raw): duck, honey, five-spice powder
# ✅ Parsed Ground Truth (list): ['duck', 'honey', 'five-spice powder']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Honey-Glazed Five-Spice Duck",
#   "chosen_from": "Chinese Cuisine",
#   "ingredients": [
#     "1 duck, about 4-5 pounds",
#     "2 tablespoons honey",
#     "1 tablespoon five-spice powder",
#     "1 tablespoon soy sauce",
#     "1 teaspoon salt",
#     "1/2 teaspoon black pepper",
#     "2 cloves garlic, minced",
#     "1 inch ginger, minced"
#   ],
#   "steps": [
#     "Preheat oven to 375°F (190°C).",
#     "Rinse the duck inside and out and pat dry with paper towels.",
#     "In a small bowl, combine honey, five-spice powder, soy sauce, salt, pepper, garlic, and ginger to create a marinade.",
#     "Rub the marinade all over the duck, including under the skin if possible. You can gently loosen the skin to make this easier.",
#     "Place the duck on a roasting rack in a roasting pan.",
#
#
# 🥬 Extracted Ingredients: ['1 duck, about 4-5 pounds', '2 tablespoons honey', '1 tablespoon five-spice powder', '1 tablespoon soy sauce', '1 teaspoon salt', '1/2 teaspoon black pepper', '2 cloves garlic, minced', '1 inch ginger, minced']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.375,
#   "f1": 0.5454545454545454,
#   "pairs": [
#     [
#       "duck",
#       "1 duck about 4-5 pounds"
#     ],
#     [
#       "honey",
#       "2 tablespoons honey"
#     ],
#     [
#       "five-spice powder",
#       "1 tablespoon five-spice powder"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 7/10
#
# 🔍 Prompt: I have ground pork, napa cabbage, and garlic. I want a northern Chinese dumpling filling idea.
# 🎯 Ground Truth (raw): ground pork, napa cabbage, garlic
# ✅ Parsed Ground Truth (list): ['ground pork', 'napa cabbage', 'garlic']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Napa Cabbage & Pork Dumplings (Shuijiao) - Northern Chinese Style",
#   "chosen_from": "Utilizing available ingredients",
#   "ingredients": [
#     "1 pound ground pork",
#     "1/2 large head of Napa cabbage, finely chopped and salted",
#     "4 cloves garlic, minced",
#     "1 tablespoon soy sauce",
#     "1 tablespoon sesame oil",
#     "1 teaspoon grated fresh ginger (optional)",
#     "1/2 teaspoon white pepper",
#     "Dumpling wrappers (store-bought or homemade)",
#     "Water for sealing dumplings"
#   ],
#   "steps": [
#     "Prepare the cabbage: Finely chop the Napa cabbage and place it in a colander. Sprinkle generously with salt and let it sit for at least 30 minutes to an hour, or until the cabbage has softened and released water.",
#     "Squeeze out excess water: Rinse the sa
#
# 🥬 Extracted Ingredients: ['1 pound ground pork', '1/2 large head of Napa cabbage, finely chopped and salted', '4 cloves garlic, minced', '1 tablespoon soy sauce', '1 tablespoon sesame oil', '1 teaspoon grated fresh ginger (optional)', '1/2 teaspoon white pepper', 'Dumpling wrappers (store-bought or homemade)', 'Water for sealing dumplings']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.3333333333333333,
#   "f1": 0.5,
#   "pairs": [
#     [
#       "ground pork",
#       "1 pound ground pork"
#     ],
#     [
#       "napa cabbage",
#       "1 2 large head of napa cabbage finely chopped and salted"
#     ],
#     [
#       "garlic",
#       "4 cloves garlic minced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 8/10
#
# 🔍 Prompt: I have noodles, sesame paste, and cucumber. I want a cold Sichuan-style noodle dish.
# 🎯 Ground Truth (raw): noodles, sesame paste, cucumber
# ✅ Parsed Ground Truth (list): ['noodles', 'sesame paste', 'cucumber']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cold Sesame Noodles with Cucumber (Sichuan Style)",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "8 oz noodles (wheat or egg noodles)",
#     "2 tablespoons sesame paste (tahini can be substituted)",
#     "2 tablespoons soy sauce",
#     "1 tablespoon rice vinegar",
#     "1 tablespoon chili oil (or to taste)",
#     "1 teaspoon sugar",
#     "1 clove garlic, minced",
#     "1/2 teaspoon grated fresh ginger",
#     "1/4 cup cold water (or as needed to thin)",
#     "1 cucumber, thinly sliced",
#     "Optional: Chopped peanuts, sesame seeds, scallions for garnish"
#   ],
#   "steps": [
#     "Cook noodles according to package directions, until al dente. Rinse immediately under cold water to stop cooking and drain well.",
#     "In a large bowl, whisk together the sesame paste, s
#
# 🥬 Extracted Ingredients: ['8 oz noodles (wheat or egg noodles)', '2 tablespoons sesame paste (tahini can be substituted)', '2 tablespoons soy sauce', '1 tablespoon rice vinegar', '1 tablespoon chili oil (or to taste)', '1 teaspoon sugar', '1 clove garlic, minced', '1/2 teaspoon grated fresh ginger', '1/4 cup cold water (or as needed to thin)', '1 cucumber, thinly sliced', 'Optional: Chopped peanuts, sesame seeds, scallions for garnish']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.2727272727272727,
#   "f1": 0.42857142857142855,
#   "pairs": [
#     [
#       "noodles",
#       "8 oz noodles wheat or egg noodles"
#     ],
#     [
#       "sesame paste",
#       "2 tablespoons sesame paste tahini can be substituted"
#     ],
#     [
#       "cucumber",
#       "1 cucumber thinly sliced"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 9/10
#
# 🔍 Prompt: I have fish fillet, chili peppers, and bean sprouts. I want to make boiled fish in spicy broth.
# 🎯 Ground Truth (raw): fish fillet, chili peppers, bean sprouts
# ✅ Parsed Ground Truth (list): ['fish fillet', 'chili peppers', 'bean sprouts']
# 📦 Retrieved 3 candidates from Chroma
#
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Spicy Boiled Fish with Bean Sprouts",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Fish fillet (e.g., cod, tilapia)",
#     "Chili peppers (adjust to your spice preference)",
#     "Bean sprouts",
#     "Water or fish broth",
#     "Cooking oil",
#     "Ginger, thinly sliced",
#     "Garlic, minced",
#     "Soy sauce",
#     "Salt",
#     "Sugar",
#     "White pepper",
#     "Cornstarch (optional, for thickening)"
#   ],
#   "steps": [
#     "Prepare the fish: Cut the fish fillet into bite-sized pieces. Lightly season with salt, white pepper, and a touch of cornstarch (optional).",
#     "Prepare the chili oil: Heat cooking oil in a pot or wok over medium heat. Add sliced ginger and minced garlic, and stir-fry until fragrant. Add chopped chili peppers and stir-fry for a few secon
#
# 🥬 Extracted Ingredients: ['Fish fillet (e.g., cod, tilapia)', 'Chili peppers (adjust to your spice preference)', 'Bean sprouts', 'Water or fish broth', 'Cooking oil', 'Ginger, thinly sliced', 'Garlic, minced', 'Soy sauce', 'Salt', 'Sugar', 'White pepper', 'Cornstarch (optional, for thickening)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.25,
#   "f1": 0.4,
#   "pairs": [
#     [
#       "fish fillet",
#       "fish fillet e g cod tilapia"
#     ],
#     [
#       "chili peppers",
#       "chili peppers adjust to your spice preference"
#     ],
#     [
#       "bean sprouts",
#       "bean sprouts"
#     ]
#   ]
# }
#
# ================================================================================
# 🧩 Sample 10/10
#
# 🔍 Prompt: I have tofu skin, peanuts, and vinegar. I want a refreshing cold appetizer.
# 🎯 Ground Truth (raw): tofu skin, peanuts, vinegar
# ✅ Parsed Ground Truth (list): ['tofu skin', 'peanuts', 'vinegar']
# 📦 Retrieved 3 candidates from Chroma
# Evaluating recipes: 100%|██████████| 1/1 [00:27<00:00, 27.12s/it]
# 💬 Gemini Raw Output:
#  ```json
# {
#   "recipe_name": "Cold Tofu Skin Salad with Peanuts and Vinegar",
#   "chosen_from": "User Request",
#   "ingredients": [
#     "Tofu skin (yuba)",
#     "Peanuts, roasted and lightly crushed",
#     "Rice vinegar",
#     "Soy sauce (optional)",
#     "Sesame oil (optional)",
#     "Sugar or sweetener (optional)",
#     "Chili oil or flakes (optional, for heat)",
#     "Cilantro or scallions, chopped (optional, for garnish)"
#   ],
#   "steps": [
#     "Rehydrate the tofu skin according to package directions. If using dried tofu skin, soak in warm water until softened. Fresh tofu skin can be blanched briefly in boiling water.",
#     "Drain the tofu skin and gently squeeze out excess water.",
#     "Cut the tofu skin into bite-sized pieces or strips.",
#     "In a bowl, combine the tofu skin, peanuts, and vineg
#
# 🥬 Extracted Ingredients: ['Tofu skin (yuba)', 'Peanuts, roasted and lightly crushed', 'Rice vinegar', 'Soy sauce (optional)', 'Sesame oil (optional)', 'Sugar or sweetener (optional)', 'Chili oil or flakes (optional, for heat)', 'Cilantro or scallions, chopped (optional, for garnish)']
#
# 📊 Metrics:
#  {
#   "matched": 3,
#   "recall": 1.0,
#   "precision": 0.375,
#   "f1": 0.5454545454545454,
#   "pairs": [
#     [
#       "tofu skin",
#       "tofu skin yuba"
#     ],
#     [
#       "peanuts",
#       "peanuts roasted and lightly crushed"
#     ],
#     [
#       "vinegar",
#       "rice vinegar"
#     ]
#   ]
# }
#
# ✅ 所有指标已保存到: outputs/baseline\metrics_results.csv

# %%
results_df.to_csv(results_path, index=False, encoding="utf-8-sig")
